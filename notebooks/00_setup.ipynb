# %% [markdown]
# # 00 – Environment Setup
#
# Verify that all dependencies are installed and the project structure is correct.

# %%
import sys, importlib
sys.path.insert(0, '..')

required = ['pandas', 'numpy', 'sklearn', 'hmmlearn', 'joblib', 'matplotlib', 'seaborn']
for pkg in required:
    try:
        importlib.import_module(pkg)
        print(f'  OK  {pkg}')
    except ImportError:
        print(f'MISSING {pkg}')
# Out:
#   OK  pandas
#   OK  numpy
#   OK  sklearn
#   OK  hmmlearn
#   OK  joblib
#   OK  matplotlib
#   OK  seaborn

# %%
from src.config import FULL_HOUSES, TARGET_APPLIANCES, RESAMPLE_RULE
print('Houses:', FULL_HOUSES)
print('Appliances:', TARGET_APPLIANCES)
print('Resample rule:', RESAMPLE_RULE)
# Out:
# Houses: [2, 3, 4, 5, 8, 9, 15, 20]
# Appliances: ['kettle', 'microwave', 'fridge', 'washing_machine']
# Resample rule: 1min

# %%
from pathlib import Path
raw = Path('../data/raw')
if raw.exists():
    csvs = sorted(raw.glob('House_*.csv'))
    print(f'Found {len(csvs)} house CSV(s) in data/raw/')
    for c in csvs:
        print(' ', c.name)
else:
    print('WARNING: data/raw/ not found. Place REFIT CSV files there before running.')
# Out:
# Found 20 house CSV(s) in data/raw/
#   House_1.csv
#   House_10.csv
#   House_11.csv
#   House_12.csv
#   House_13.csv
#   House_15.csv
#   House_16.csv
#   House_17.csv
#   House_18.csv
#   House_19.csv
#   House_2.csv
#   House_20.csv
#   House_21.csv
#   House_3.csv
#   House_4.csv
#   House_5.csv
#   House_6.csv
#   House_7.csv
#   House_8.csv
#   House_9.csv
