# %% [markdown]
# # 03 – Appliance Mapping Check
#
# Verify that HOUSE_MAP correctly maps raw columns to standard appliance names.

# %%
import sys
sys.path.insert(0, '..')
import pandas as pd
import matplotlib.pyplot as plt
from src.config import FULL_HOUSES, TARGET_APPLIANCES
from src.mapping import HOUSE_MAP, standardize
from src.io_refit import load_house
from src.cleaning import clean_resample

# %%
print('HOUSE_MAP:')
for h, mapping in HOUSE_MAP.items():
    print(f'  House {h}:', {k: v for k, v in mapping.items() if k != 'mains'})
# Out:
# HOUSE_MAP:
#   House 2: {'fridge': 'Appliance1', 'washing_machine': 'Appliance2', 'microwave': 'Appliance5', 'kettle': 'Appliance8'}
#   House 3: {'fridge': 'Appliance2', 'washing_machine': 'Appliance6', 'microwave': 'Appliance8', 'kettle': 'Appliance9'}
#   House 4: {'fridge': ['Appliance1', 'Appliance3'], 'washing_machine': ['Appliance4', 'Appliance5'], 'microwave': 'Appliance8', 'kettle': 'Appliance9'}
#   House 5: {'fridge': 'Appliance1', 'washing_machine': 'Appliance3', 'microwave': 'Appliance7', 'kettle': 'Appliance8'}
#   House 8: {'fridge': 'Appliance1', 'washing_machine': 'Appliance4', 'microwave': 'Appliance8', 'kettle': 'Appliance9'}
#   House 9: {'fridge': 'Appliance1', 'washing_machine': 'Appliance3', 'microwave': 'Appliance6', 'kettle': 'Appliance7'}
#   House 15: {'fridge': 'Appliance1', 'washing_machine': 'Appliance3', 'microwave': 'Appliance7', 'kettle': 'Appliance8'}
#   House 20: {'fridge': 'Appliance1', 'washing_machine': 'Appliance4', 'microwave': 'Appliance8', 'kettle': 'Appliance9'}

# %%
# Spot check House 4 (summed channels)
house_id = 4
raw = load_house(house_id, raw_dir='../data/raw')
std = standardize(raw, house_id, appliances=TARGET_APPLIANCES)
clean, _ = clean_resample(std)
print(clean.describe())
# Out:
# Ambiguous local timestamps for House 4; falling back to Unix epoch column.
#                mains         kettle      microwave         fridge  \
# count  793904.000000  793960.000000  793852.000000  793959.000000
# mean      376.775928      10.696873       1.918784      46.427390
# std       383.053900     132.564404       1.373578      60.034388
# min         0.000000       0.000000       0.000000       0.000000
# 25%       195.444444       0.000000       2.000000       0.000000
# 50%       298.714286       0.000000       2.000000       0.000000
# 75%       471.200000       0.000000       2.000000     123.000000
# max      5090.000000    2006.000000      38.000000     256.000000
#
#        washing_machine
# count    791146.000000
# mean          0.599203
# std           4.045607
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         123.000000
