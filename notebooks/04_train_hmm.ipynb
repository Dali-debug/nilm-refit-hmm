# %% [markdown]
# # 04 – HMM Training (LOHO)
#
# Train one GaussianHMM per appliance using Leave-One-House-Out splits.
# Models are saved to `models/loho_<test_house>/`.

# %%
# Run the training script directly
import subprocess, sys
result = subprocess.run(
    [sys.executable, '../scripts/train_loho.py', '--config', '../configs/config.yaml'],
    capture_output=True, text=True
)
print(result.stdout)
if result.returncode != 0:
    print('STDERR:', result.stderr)

# %%
# Inspect one saved model
import sys, pathlib
sys.path.insert(0, str(pathlib.Path().resolve().parent))

from src.hmm_model import load_model
from src.load_refit import load_config
import numpy as np

cfg = load_config('../configs/config.yaml')
test_house = cfg['houses'][0]
model = load_model(f'../models/loho_{test_house}/kettle.pkl')

print('Means (W):', np.sort(model.means_.ravel()))
print('Transition matrix:')
print(model.transmat_)
