# %% [markdown]
# # 07 – Results Tables and Plots
#
# Aggregate LOHO results and create summary tables and figures.

# %%
import sys
sys.path.insert(0, '..')
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from src.config import RESULTS_DIR
from src.plots import plot_metrics_bar

# %%
metrics_path = Path('..') / RESULTS_DIR / 'metrics.csv'
if not metrics_path.exists():
    print('No metrics found. Run run_loho_infer.py first.')
else:
    df = pd.read_csv(metrics_path)
    print(df.to_string(index=False))

# %%
if 'df' in dir() and len(df) > 0:
    for metric in ['NRMSE', 'F1', 'REE']:
        fig = plot_metrics_bar(df, metric=metric)
        plt.show()
    # Summary stats
    print('\nMean metrics per appliance:')
    print(df.groupby('appliance')[['MAE','RMSE','NRMSE','REE','F1']].mean().round(4).to_string())
